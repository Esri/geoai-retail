# %%
# %matplotlib inline

from arcgis.features import GeoAccessor
from arcgis.geometry import Geometry
import pandas as pd
import os
import numpy as np
import itertools
from sklearn.pipeline import Pipeline

import sys
sys.path.append('../src/geoai-retail')
from data import *

gdb_int = r'D:\\projects\\geoai-retail\\data\\interim\\interim.gdb'
block_group_fc = os.path.join(gdb_int, 'block_groups_enriched')
trips_fc = os.path.join(gdb_int, 'trips')

gdb_raw = r'D:\\projects\\geoai-retail\\data\\raw\\raw.gdb'
stores_fc = os.path.join(gdb_raw, 'coffee')

# %load_ext autoreload
# %autoreload 2

# %%
block_group_df = GeoAccessor.from_featureclass(block_group_fc)
trips_df = GeoAccessor.from_featureclass(trips_fc)
stores_df = GeoAccessor.from_featureclass(stores_fc)

# %%
bg_loader = DemographicFeatureClassToDataframe('../data/interim/alias_table.csv')
bg_df = bg_loader.fit_transform(block_group_fc)
bg_df.sample(5)
# Out:
#               gender_pop0_cy  gender_pop5_cy  gender_pop10_cy  \
# ID
# 410470020003           133.0           150.0            181.0
# 530610412021           110.0           106.0             86.0
# 530530617004            55.0            49.0             42.0
# 530610410003            70.0            75.0             76.0
# 410191600004            79.0            79.0             80.0
#
#               gender_pop15_cy  gender_pop20_cy  gender_pop25_cy  \
# ID
# 410470020003            195.0            156.0            124.0
# 530610412021             70.0             94.0            116.0
# 530530617004             50.0             73.0             95.0
# 530610410003             71.0             92.0            103.0
# 410191600004             75.0             76.0             96.0
#
#               gender_pop30_cy  gender_pop35_cy  gender_pop40_cy  \
# ID
# 410470020003            127.0            171.0            175.0
# 530610412021            116.0             94.0             94.0
# 530530617004             89.0             55.0             41.0
# 530610410003            113.0            123.0            113.0
# 410191600004             97.0             83.0             62.0
#
#               gender_pop45_cy  \
# ID
# 410470020003            184.0
# 530610412021             95.0
# 530530617004             50.0
# 530610410003            111.0
# 410191600004             53.0
#
#                                     ...                          \
# ID                                  ...
# 410470020003                        ...
# 530610412021                        ...
# 530530617004                        ...
# 530610410003                        ...
# 410191600004                        ...
#
#               educationalattainment_ged_cy  educationalattainment_smcoll_cy  \
# ID
# 410470020003                          24.0                            370.0
# 530610412021                           0.0                            233.0
# 530530617004                          53.0                            130.0
# 530610410003                          42.0                            355.0
# 410191600004                          65.0                            399.0
#
#               educationalattainment_asscdeg_cy  \
# ID
# 410470020003                             144.0
# 530610412021                              59.0
# 530530617004                              36.0
# 530610410003                             152.0
# 410191600004                              18.0
#
#               educationalattainment_bachdeg_cy  \
# ID
# 410470020003                             475.0
# 530610412021                              33.0
# 530530617004                              83.0
# 530610410003                             217.0
# 410191600004                               0.0
#
#               educationalattainment_graddeg_cy  \
# ID
# 410470020003                             314.0
# 530610412021                               0.0
# 530530617004                              36.0
# 530610410003                              27.0
# 410191600004                              20.0
#
#               educationalattainment_educbasecy  households_acshhbpov  \
# ID
# 410470020003                            1652.0                  18.0
# 530610412021                             872.0                 229.0
# 530530617004                             506.0                  64.0
# 530610410003                            1183.0                 133.0
# 410191600004                             714.0                 146.0
#
#               households_acshhapov  households_acsbpovmcf  \
# ID
# 410470020003                 834.0                   18.0
# 530610412021                 457.0                   30.0
# 530530617004                 168.0                    0.0
# 530610410003                 569.0                    0.0
# 410191600004                 163.0                  108.0
#
#                                                           SHAPE
# ID
# 410470020003  {"rings": [[[-122.99843999899997, 44.885180000...
# 530610412021  {"rings": [[[-122.21232999899996, 47.931250000...
# 530530617004  {"rings": [[[-122.44629999999995, 47.233740000...
# 530610410003  {"rings": [[[-122.20657999999997, 47.949440000...
# 410191600004  {"rings": [[[-123.41537849999997, 43.115381000...
#
# [5 rows x 1524 columns]

# %%
store_pipe = Pipeline([
    ('loader', EsriLocatedStoresFeatureClassToDataframe()),
    ('count_reclass', StoreClassifyByCount(store_count_threshold=3))
])
store_df = store_pipe.fit_transform(stores_fc)
store_df.sample(5)
# Out:
#                      store_class       store_class_original  \
# store_id
# 417755893                  OTHER  LOTUS & BEAN ESPRESSO BAR
# 232331066              STARBUCKS                  STARBUCKS
# 396149163              STARBUCKS                  STARBUCKS
# 632063715              STARBUCKS                  STARBUCKS
# 706070674  DUTCH BROTHERS COFFEE      DUTCH BROTHERS COFFEE
#
#                                                        SHAPE
# store_id
# 417755893  {"x": -122.67479999964382, "y": 45.51899999996...
# 232331066  {"x": -122.67160000001041, "y": 45.63939999967...
# 396149163  {"x": -122.33589999959293, "y": 45.57850000027...
# 632063715  {"x": -122.97439999982186, "y": 45.52079999950...
# 706070674  {"x": -122.87830000045602, "y": 45.75159999956...

# %%
web_map = store_df[store_df['store_class'] == "UNCLE GARY'S COFFEE EMPORIUM"].spatial.plot()
web_map.basemap ='streets-relief-vector'
web_map
# Out:
# C:\Users\joel5174\AppData\Local\ESRI\conda\envs\arcgis-head\lib\site-packages\arcgis\features\geo\_accessor.py:2208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._data['OBJECTID'] = list(range(1, self._data.shape[0] + 1))
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-b233aff3-5c25-4358-9f70-afc6ae0a3f41"><img src=""></img></div>

# %%
origin_sum_pipe = Pipeline([
    ('summ_trips', SummarizeInrixTripsByOriginAndDestination()),
    ('add_block_group_df', AddPolygonOriginDataframeToInrixTripSummaryDataframe(bg_df)),
    ('calc_mkt_pen', CalculateMarketPenetration('trip_count', 'householdtotals_tothh_cy'))
])
origin_sum_df = origin_sum_pipe.fit_transform(trips_df)
origin_sum_df.head(5)
# Out:
#       origin_id  destination_id  trip_distance_miles  trip_time_minutes  \
# 0  060930004001       219649035           311.607615         272.600000
# 1  060930004001       718176685           261.898556         270.266667
# 2  060930004001       723838910           311.607615         272.600000
# 3  410019502002       105830012           304.353730         276.283333
# 4  410019502002       732273983           304.353730         276.283333
#
#    trip_count  gender_pop0_cy  gender_pop5_cy  gender_pop10_cy  \
# 0           1            19.0            20.0             39.0
# 1           1            19.0            20.0             39.0
# 2           1            19.0            20.0             39.0
# 3           1            78.0            75.0             71.0
# 4           1            78.0            75.0             71.0
#
#    gender_pop15_cy  gender_pop20_cy         ...          \
# 0             19.0             23.0         ...
# 1             19.0             23.0         ...
# 2             19.0             23.0         ...
# 3             72.0             78.0         ...
# 4             72.0             78.0         ...
#
#    educationalattainment_smcoll_cy  educationalattainment_asscdeg_cy  \
# 0                            169.0                              37.0
# 1                            169.0                              37.0
# 2                            169.0                              37.0
# 3                            264.0                              18.0
# 4                            264.0                              18.0
#
#    educationalattainment_bachdeg_cy  educationalattainment_graddeg_cy  \
# 0                              37.0                              34.0
# 1                              37.0                              34.0
# 2                              37.0                              34.0
# 3                             128.0                              30.0
# 4                             128.0                              30.0
#
#    educationalattainment_educbasecy  households_acshhbpov  \
# 0                             507.0                  42.0
# 1                             507.0                  42.0
# 2                             507.0                  42.0
# 3                             792.0                 170.0
# 4                             792.0                 170.0
#
#    households_acshhapov  households_acsbpovmcf  \
# 0                 226.0                   22.0
# 1                 226.0                   22.0
# 2                 226.0                   22.0
# 3                 294.0                   19.0
# 4                 294.0                   19.0
#
#                                                SHAPE  market_penetration
# 0  {'rings': [[[-122.368049999, 42.00933000000003...            0.003344
# 1  {'rings': [[[-122.368049999, 42.00933000000003...            0.003344
# 2  {'rings': [[[-122.368049999, 42.00933000000003...            0.003344
# 3  {'rings': [[[-117.82904999999994, 44.777120000...            0.002008
# 4  {'rings': [[[-117.82904999999994, 44.777120000...            0.002008
#
# [5 rows x 1530 columns]

# %%
from data import *

proximity_metric_fields = ['trip_distance_miles', 'trip_time_minutes']
proximity_sort_field = 'trip_distance_miles'
measurement_metric_field = 'market_penetration'

bg_trips_pipe = Pipeline([
    ('summ_trips', SummarizeInrixTripsByOriginAndDestination()),
    ('add_stores', AddStoresDataframeToTripsDataframe(store_df)),
    ('add_block_groups', AddBlockGroupDataframeToTripsDataframe(origin_sum_df)),
    ('calc_dest_metrics', CalculateOriginProximityMetricsByStoreClass(proximity_metric_fields, 
                                                                     proximity_sort_field, 
                                                                     measurement_metric_field)),
    ('add_demog', AddDemographicsToProximityMetrics(bg_df))
])

final_df = bg_trips_pipe.fit_transform(trips_df)
final_df.head()
# Out:
#               gender_pop0_cy  gender_pop5_cy  gender_pop10_cy  \
# origin_id
# 410030103003            28.0            43.0             53.0
# 410110001001            29.0            30.0             32.0
# 410110001002            13.0            15.0             17.0
# 410110001003            29.0            29.0             31.0
# 410110001004            43.0            47.0             59.0
#
#               gender_pop15_cy  gender_pop20_cy  gender_pop25_cy  \
# origin_id
# 410030103003             45.0             43.0             52.0
# 410110001001             29.0             30.0             29.0
# 410110001002             18.0             18.0             21.0
# 410110001003             36.0             56.0             74.0
# 410110001004             48.0             42.0             52.0
#
#               gender_pop30_cy  gender_pop35_cy  gender_pop40_cy  \
# origin_id
# 410030103003             47.0             38.0             36.0
# 410110001001             27.0             40.0             38.0
# 410110001002             21.0             22.0             22.0
# 410110001003             83.0             73.0             63.0
# 410110001004             51.0             56.0             50.0
#
#               gender_pop45_cy  \
# origin_id
# 410030103003             56.0
# 410110001001             38.0
# 410110001002             37.0
# 410110001003             87.0
# 410110001004             57.0
#
#                                     ...                         \
# origin_id                           ...
# 410030103003                        ...
# 410110001001                        ...
# 410110001002                        ...
# 410110001003                        ...
# 410110001004                        ...
#
#               trip_time_minutes_OTHER_03  trip_time_minutes_STARBUCKS_01  \
# origin_id
# 410030103003                         NaN                       81.050000
# 410110001001                         NaN                             NaN
# 410110001002                         NaN                      206.733333
# 410110001003                         NaN                             NaN
# 410110001004                         NaN                             NaN
#
#               trip_time_minutes_STARBUCKS_02  trip_time_minutes_STARBUCKS_03  \
# origin_id
# 410030103003                             NaN                             NaN
# 410110001001                             NaN                             NaN
# 410110001002                             NaN                             NaN
# 410110001003                             NaN                             NaN
# 410110001004                             NaN                             NaN
#
#               trip_time_minutes_STUMPTOWN_COFFEE_ROASTERS_01  \
# origin_id
# 410030103003                                             NaN
# 410110001001                                             NaN
# 410110001002                                             NaN
# 410110001003                                             NaN
# 410110001004                                             NaN
#
#               trip_time_minutes_STUMPTOWN_COFFEE_ROASTERS_02  \
# origin_id
# 410030103003                                             NaN
# 410110001001                                             NaN
# 410110001002                                             NaN
# 410110001003                                             NaN
# 410110001004                                             NaN
#
#               trip_time_minutes_STUMPTOWN_COFFEE_ROASTERS_03  \
# origin_id
# 410030103003                                             NaN
# 410110001001                                             NaN
# 410110001002                                             NaN
# 410110001003                                             NaN
# 410110001004                                             NaN
#
#               trip_time_minutes_UNCLE_GARYS_COFFEE_EMPORIUM_01  \
# origin_id
# 410030103003                                               NaN
# 410110001001                                               NaN
# 410110001002                                               NaN
# 410110001003                                               NaN
# 410110001004                                               NaN
#
#               trip_time_minutes_UNCLE_GARYS_COFFEE_EMPORIUM_02  \
# origin_id
# 410030103003                                               NaN
# 410110001001                                               NaN
# 410110001002                                               NaN
# 410110001003                                               NaN
# 410110001004                                               NaN
#
#               trip_time_minutes_UNCLE_GARYS_COFFEE_EMPORIUM_03
# origin_id
# 410030103003                                               NaN
# 410110001001                                               NaN
# 410110001002                                               NaN
# 410110001003                                               NaN
# 410110001004                                               NaN
#
# [5 rows x 1624 columns]

# %%
final_fs = final_df.spatial.to_featureset()
final_fs
# Out:
# <FeatureSet> 6963 features

# %%
final_fs.save(gdb_int, 'block_group_final')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\ESRI\conda\envs\arcgis-head\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\ESRI\conda\envs\arcgis-head\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\ESRI\conda\envs\arcgis-head\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# <ipython-input-10-76ec9fc93c0f> in <module>()
# ----> 1 final_fs.save(gdb_int, 'block_group_final')
#
# ~\AppData\Local\ESRI\conda\envs\arcgis-head\lib\site-packages\arcgis\features\feature.py in save(self, save_location, out_name, encoding)
#    1089             del writer
#    1090             res = json_to_featureclass(json_file=temp_file,
# -> 1091                                        out_fc=os.path.join(save_location, out_name))
#    1092             os.remove(temp_file)
#    1093         return res
#
# ~\AppData\Local\ESRI\conda\envs\arcgis-head\lib\site-packages\arcgis\_impl\common\_spatial.py in json_to_featureclass(json_file, out_fc)
#      21     if hasArcPy:
#      22         return arcpy.JSONToFeatures_conversion(in_json_file=json_file,
# ---> 23                                                out_features=out_fc)[0]
#      24     return None
#      25 #----------------------------------------------------------------------
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\conversion.py in JSONToFeatures(in_json_file, out_features, geometry_type)
#     432         return retval
#     433     except Exception as e:
# --> 434         raise e
#     435
#     436
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\conversion.py in JSONToFeatures(in_json_file, out_features, geometry_type)
#     429     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#     430     try:
# --> 431         retval = convertArcObjectToPythonObject(gp.JSONToFeatures_conversion(*gp_fixargs((in_json_file, out_features, geometry_type), True)))
#     432         return retval
#     433     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     496         val = getattr(self._gp, attr)
#     497         if callable(val):
# --> 498             return lambda *args: val(*gp_fixargs(args, True))
#     499         else:
#     500             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 001558: Error parsing json file 'C:\Users\joel5174\AppData\Local\Temp\8f3694f2da0347e8b8c8c3e1abe69b6e.json'. The value type is incompatible with the field type. [dest_id_OTHER_01]
# Failed to execute (JSONToFeatures).

# %%
final_df.to_csv(r'D:\\projects\\geoai-retail\\data\\interim\\block_group_final.csv')

# %%
final_nonspatial_df = final_df.drop('SHAPE', axis=1)
final_nonspatial_df.to_csv(r'D:\\projects\\geoai-retail\\data\\interim\\block_group_final_nonspatial.csv')
