# %%
from arcgis import GeoAccessor

import sys
sys.path.append('../../src')

from geoai_retail import proximity_local as proximity

# %load_ext autoreload
# %autoreload 2

# %%
network_dataset = r'D:\arcgis\ba_data\Data\Streets Data\NorthAmerica.gdb\Routing\Routing_ND'
destination_count = 6

# %%
origin_df = GeoAccessor.from_featureclass('../../src/tests/test_data.gdb/block_groups')
# origin_df = proximity.prep_sdf_for_nearest(origin_df, 'ID')

# origin_df.head()

GeoAccessor.from_featureclass('../../src/tests/test_data.gdb/block_groups')

# %%
dest_df = GeoAccessor.from_featureclass('../../src/tests/test_data.gdb/coffee_pdx')
dest_df = proximity.prep_sdf_for_nearest(dest_df, 'LOCNUM')

dest_df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-de257b5006c0> in <module>
#       2 dest_df = GeoAccessor.from_featureclass('../../src/tests/test_data.gdb/coffee_pdx')
#       3
# ----> 4 origin_df = proximity.prep_sdf_for_nearest(origin_df, 'ID')
#       5 dest_df = proximity.prep_sdf_for_nearest(dest_df, 'LOCNUM')
#       6
#
# D:\projects\geoai-retail\src\geoai_retail\proximity_local.py in prep_sdf_for_nearest(df, id_fld, weighting_points)
#      57     """
#      58     # par down the input dataframe to just the columns needed
# ---> 59     df = df[[id_fld, 'SHAPE']].copy()
#      60
#      61     # rename the columns to follow the schema needed for routing
#
# TypeError: 'NoneType' object is not subscriptable

# %%
closest_df = proximity._get_closest_df_arcpy(origin_df, dest_df, destination_count, network_dataset)
closest_df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\ops.py in f(self, other)
#    2090
# -> 2091         other = _align_method_FRAME(self, other, axis=None)
#    2092
#
# ...

# %%
closest_reformat_df = proximity.reformat_closest_result_dataframe(closest_df)

closest_reformat_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d07c44d16ad2> in <module>
# ----> 1 closest_reformat_df = proximity.reformat_closest_result_dataframe(closest_df)
#       2
#       3 closest_reformat_df.head(10)
#
# NameError: name 'proximity' is not defined

# %%
closest_final_df = proximity.explode_closest_rank_dataframe(closest_reformat_df)

closest_final_df.sample(10)
# Out:
#         origin_id destination_id_01  proximity_traveltime_01  \
# 127  410670318054         637457904                 5.808243
# 75   410670310044         949745442                 2.322189
# 113  410670317043         637457904                 4.030717
# 90   410670313001         236918645                 2.226020
# 62   410670308053         484176375                 3.145648
# 195  410510063001         523661049                 4.457167
# 117  410670317052         637457904                 3.235813
# 84   410670311001         625932082                 3.346007
# 83   410670310064         710847142                 1.582780
# 174  410050201001         523638237                 8.886705
#
#      proximity_kilometers_01 destination_id_02  proximity_traveltime_02  \
# 127                 1.852676         724619411                 7.028494
# 75                  0.974017         723839071                 3.341061
# 113                 1.668458         724619411                 9.609248
# ...

# %%
from geoai_retail import utils
from arcgis.gis import GIS
gis = GIS()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-736e0e09a7f8> in <module>
# ----> 1 from geoai_retail import utils
#       2 from arcgis.gis import GIS
#       3 gis = GIS()
#
# ModuleNotFoundError: No module named 'geoai_retail'

# %%
env = utils.Environment()

# %%
env.gis

# %%
import arcgis

# %%
arcgis.env.active_gis
