# %%
import os
from pathlib import Path
import sys

from arcgis.features import GeoAccessor
import pandas as pd

from ba_tools import utils

# %%
data = Path(os.path.abspath('../../data'))
interim_dir = data/'interim'
raw_dir = data/'raw'
raw_gdb = raw_dir/'raw.gdb'

closest_brand = interim_dir/'closest_store.csv'
closest_comp = interim_dir/'closest_competition.csv'
origin_demographics = interim_dir/'origin_enrich_all.csv'
inrix_trips = interim_dir/'cust_count_inrix.csv'

comp_fc = raw_gdb/'sea_ace_comp'
comp_name_fld = 'CONAME'

# %%
closest_comp_df = pd.read_csv(closest_comp, index_col=0)
closest_comp_df.head()
# Out:
#       origin_id  destination_id_01  proximity_competition_traveltime_01  \
# 0  530530701003          388273260                            27.324552
# 1  530530714071          718164872                             5.290436
# 2  530530714072          718164872                             7.551801
# 3  530530714073          502088164                             8.712262
# 4  530530714112          502088164                             2.551648
#
#    proximity_competition_kilometers_01  destination_id_02  \
# 0                            24.844065          174262691
# 1                             3.543129          996721817
# 2                             4.354229          502088164
# 3                             4.531160          718164872
# 4                             0.957319          667567382
#
#    proximity_competition_traveltime_02  proximity_competition_kilometers_02  \
# 0                            26.486351                            25.466621
# 1                            10.072421                             5.099409
# 2                             7.940114                             5.186840
# 3                             9.507141                             4.721377
# 4                             7.529261                             5.468934
#
#    destination_id_03  proximity_competition_traveltime_03  \
# 0          679623777                            30.496295
# 1          502088164                             8.464914
# 2          996721817                            12.333787
# 3          996721817                            11.474098
# 4          460555345                             6.571241
#
#    proximity_competition_kilometers_03  destination_id_04  \
# 0                            25.960217          403218374
# 1                             6.134528          805003878
# 2                             5.910509          460555345
# 3                             6.162934          460555345
# 4                             6.268874          718164872
#
#    proximity_competition_traveltime_04  proximity_competition_kilometers_04  \
# 0                            30.669763                            26.656119
# 1                            12.530292                             8.456627
# 2                             9.562275                             6.501900
# 3                            13.333669                             7.594656
# 4                            10.085421                             6.620393
#
#    destination_id_05  proximity_competition_traveltime_05  \
# 0          948351200                            33.274677
# 1          401706143                            14.085878
# 2          805003878                            13.746727
# 3          667567382                            15.409227
# 4          667588727                            11.028254
#
#    proximity_competition_kilometers_05  destination_id_06  \
# 0                            31.095850            2890986
# 1                             9.183802          460555345
# 2                             9.084260          667567382
# 3                            10.195625          667588727
# 4                             7.036569          996721817
#
#    proximity_competition_traveltime_06  proximity_competition_kilometers_06
# 0                            41.531836                            34.025060
# 1                            12.203891                             9.231713
# 2                            12.891244                            10.126950
# 3                            17.839612                            11.169613
# 4                            11.014189                             7.203595

# %%
comp_df = GeoAccessor.from_featureclass(str(comp_fc))
comp_df = comp_df[['LOCNUM', 'CONAME', 'SHAPE']].copy()
comp_df.columns = ['dest_id', 'dest_name', 'SHAPE']
comp_df.head()
# Out:
#      dest_id                     dest_name  \
# 0  460555345         CAPITOL LUMBER & DOOR
# 1  502088164         BUILDERS FIRST SOURCE
# 2  718164872     RANDLES SURE GROW TOPSOIL
# 3  805003878  NORTHERN ACOUSTICAL SYSTS CO
# 4  216099309       LOWE'S HOME IMPROVEMENT
#
#                                                SHAPE
# 0  {"x": -122.36899999999997, "y": 47.01870000000...
# 1  {"x": -122.41119999999995, "y": 47.06890000000...
# 2  {"x": -122.35839999999996, "y": 47.08280000000...
# 3  {"x": -122.29459999999995, "y": 47.07650000000...
# 4  {"x": -122.50489999999996, "y": 47.16760000000...

# %%
comp_cat_df = utils.add_store_name_category(comp_df, 'dest_name', location_count_threshold=1)
comp_cat_df.head()
# Out:
#      dest_id                     dest_name  \
# 0  460555345         CAPITOL LUMBER & DOOR
# 1  502088164         BUILDERS FIRST SOURCE
# 2  718164872     RANDLES SURE GROW TOPSOIL
# 3  805003878  NORTHERN ACOUSTICAL SYSTS CO
# 4  216099309       LOWE'S HOME IMPROVEMENT
#
#                                                SHAPE       dest_name_category
# 0  {"x": -122.36899999999997, "y": 47.01870000000...              INDEPENDENT
# 1  {"x": -122.41119999999995, "y": 47.06890000000...    BUILDERS FIRST SOURCE
# 2  {"x": -122.35839999999996, "y": 47.08280000000...              INDEPENDENT
# 3  {"x": -122.29459999999995, "y": 47.07650000000...              INDEPENDENT
# 4  {"x": -122.50489999999996, "y": 47.16760000000...  LOWE'S HOME IMPROVEMENT

# %%
comp_final_df = utils.add_metric_by_dest(closest_comp_df, comp_cat_df, 'dest_id', 'dest_name_category', get_dummies=True)
keep_cols = [c for c in comp_final_df.columns if not c.startswith('destination_id')]
comp_final_df = comp_final_df[keep_cols].copy()
comp_final_df.set_index('origin_id', inplace=True, drop=True)
comp_final_df.head()
# Out:
#               proximity_competition_traveltime_01  \
# origin_id
# 530530701003                            27.324552
# 530530714071                             5.290436
# 530530714072                             7.551801
# 530530714073                             8.712262
# 530530714112                             2.551648
#
#               proximity_competition_kilometers_01  \
# origin_id
# 530530701003                            24.844065
# 530530714071                             3.543129
# 530530714072                             4.354229
# 530530714073                             4.531160
# 530530714112                             0.957319
#
#               proximity_competition_traveltime_02  \
# origin_id
# 530530701003                            26.486351
# 530530714071                            10.072421
# 530530714072                             7.940114
# 530530714073                             9.507141
# 530530714112                             7.529261
#
#               proximity_competition_kilometers_02  \
# origin_id
# 530530701003                            25.466621
# 530530714071                             5.099409
# 530530714072                             5.186840
# 530530714073                             4.721377
# 530530714112                             5.468934
#
#               proximity_competition_traveltime_03  \
# origin_id
# 530530701003                            30.496295
# 530530714071                             8.464914
# 530530714072                            12.333787
# 530530714073                            11.474098
# 530530714112                             6.571241
#
#               proximity_competition_kilometers_03  \
# origin_id
# 530530701003                            25.960217
# 530530714071                             6.134528
# 530530714072                             5.910509
# 530530714073                             6.162934
# 530530714112                             6.268874
#
#               proximity_competition_traveltime_04  \
# origin_id
# 530530701003                            30.669763
# 530530714071                            12.530292
# 530530714072                             9.562275
# 530530714073                            13.333669
# 530530714112                            10.085421
#
#               proximity_competition_kilometers_04  \
# origin_id
# 530530701003                            26.656119
# 530530714071                             8.456627
# 530530714072                             6.501900
# 530530714073                             7.594656
# 530530714112                             6.620393
#
#               proximity_competition_traveltime_05  \
# origin_id
# 530530701003                            33.274677
# 530530714071                            14.085878
# 530530714072                            13.746727
# 530530714073                            15.409227
# 530530714112                            11.028254
#
#               proximity_competition_kilometers_05  ...  \
# origin_id                                          ...
# 530530701003                            31.095850  ...
# 530530714071                             9.183802  ...
# 530530714072                             9.084260  ...
# 530530714073                            10.195625  ...
# 530530714112                             7.036569  ...
#
#               dest_name_category_06_MANOR_HDW_CONSTRUCTION_SUPL  \
# origin_id
# 530530701003                                                  0
# 530530714071                                                  0
# 530530714072                                                  0
# 530530714073                                                  0
# 530530714112                                                  0
#
#               dest_name_category_06_MC_LENDON_HARDWARE  \
# origin_id
# 530530701003                                         1
# 530530714071                                         0
# 530530714072                                         0
# 530530714073                                         0
# 530530714112                                         0
#
#               dest_name_category_06_MCLENDON_HARDWARE_INC  \
# origin_id
# 530530701003                                            0
# 530530714071                                            0
# 530530714072                                            0
# 530530714073                                            0
# 530530714112                                            0
#
#               dest_name_category_06_SGS_HARDWARE  \
# origin_id
# 530530701003                                   0
# 530530714071                                   0
# 530530714072                                   0
# 530530714073                                   0
# 530530714112                                   0
#
#               dest_name_category_06_SNAPON_TOOLS  \
# origin_id
# 530530701003                                   0
# 530530714071                                   0
# 530530714072                                   0
# 530530714073                                   0
# 530530714112                                   0
#
#               dest_name_category_06_TOWN_CENTER_HARDWARE  \
# origin_id
# 530530701003                                           0
# 530530714071                                           0
# 530530714072                                           0
# 530530714073                                           0
# 530530714112                                           0
#
#               dest_name_category_06_TRUE_VALUE_HARDWARE  \
# origin_id
# 530530701003                                          0
# 530530714071                                          0
# 530530714072                                          0
# 530530714073                                          0
# 530530714112                                          0
#
#               dest_name_category_06_TWEEDY_POPP_HARDWARE  \
# origin_id
# 530530701003                                           0
# 530530714071                                           0
# 530530714072                                           0
# 530530714073                                           0
# 530530714112                                           0
#
#               dest_name_category_06_US_TOOL_GROUP  \
# origin_id
# 530530701003                                    0
# 530530714071                                    0
# 530530714072                                    0
# 530530714073                                    0
# 530530714112                                    0
#
#               dest_name_category_06_WILCO_FARM_STOREPUYALLUP
# origin_id
# 530530701003                                               0
# 530530714071                                               0
# 530530714072                                               0
# 530530714073                                               0
# 530530714112                                               0
#
# [5 rows x 167 columns]

# %%
brand_df = pd.read_csv(closest_brand, index_col=0)
brand_df.head()
# Out:
#       origin_id  destination_id_01  proximity_traveltime_01  \
# 0  530530701003          677129595                43.576384
# 1  530530714071          371889957                 9.405840
# 2  530530714072          371889957                10.003444
# 3  530530714073          216082099                12.308627
# 4  530530714112          216082099                 5.292562
#
#    proximity_kilometers_01  destination_id_02  proximity_traveltime_02  \
# 0                38.513638          371889957                46.482533
# 1                 6.295963          216082099                13.296163
# 2                 6.125873          216082099                11.536480
# 3                 7.540147          371889957                13.269904
# 4                 3.556479          371889957                12.285190
#
#    proximity_kilometers_02  destination_id_03  proximity_traveltime_03  \
# 0                42.526899          427271369                52.472263
# 1                10.944308          421027779                16.006815
# 2                 8.195827          421027779                18.268181
# 3                 8.468519          421027779                20.223521
# 4                 9.615196          721714069                16.478653
#
#    proximity_kilometers_03  destination_id_04  proximity_traveltime_04  \
# 0                44.462895          421027779                55.156955
# 1                12.366455          721714069                20.814301
# 2                13.177555          721714069                22.034957
# 3                13.544703          721714069                23.035677
# 4                11.395147          421027779                19.885017
#
#    proximity_kilometers_04  destination_id_05  proximity_traveltime_05  \
# 0                44.748810          721714069                61.428125
# 1                15.290477          677129595                29.198017
# 2                15.623036          677129595                29.203660
# 3                15.164948          677129595                31.159000
# 4                15.617594          460556608                28.228815
#
#    proximity_kilometers_05  destination_id_06  proximity_traveltime_06  \
# 0                50.456415          216082099                58.905164
# 1                18.116390          460556608                35.087418
# 2                20.609116          460556608                34.472733
# 3                20.976263          460556608                35.244881
# 4                20.647334          677129595                30.820496
#
#    proximity_kilometers_06
# 0                54.642485
# 1                25.237232
# 2                25.286682
# 3                24.631002
# 4                23.049155

# %%
trips_df = pd.read_csv(inrix_trips, index_col=0)
trips_df.columns = ['origin_id', 'destination_id', 'trip_count']
trips_df.head()
# Out:
#       origin_id  destination_id  trip_count
# 0  530330001001       425477834           1
# 1  530330001001       426576447           1
# 2  530330001001       439724905           2
# 3  530330001001       714937939           2
# 4  530330001001       718542034           1

# %%
brand_fnl_df = utils.add_metric_by_origin_dest(brand_df, trips_df, 'trip_count').fillna(0.0)
brand_fnl_df.set_index('origin_id', inplace=True, drop=True)
brand_fnl_df.head()
# Out:
#               destination_id_01  proximity_traveltime_01  \
# origin_id
# 530530701003          677129595                43.576384
# 530530714071          371889957                 9.405840
# 530530714072          371889957                10.003444
# 530530714073          216082099                12.308627
# 530530714112          216082099                 5.292562
#
#               proximity_kilometers_01  destination_id_02  \
# origin_id
# 530530701003                38.513638          371889957
# 530530714071                 6.295963          216082099
# 530530714072                 6.125873          216082099
# 530530714073                 7.540147          371889957
# 530530714112                 3.556479          371889957
#
#               proximity_traveltime_02  proximity_kilometers_02  \
# origin_id
# 530530701003                46.482533                42.526899
# 530530714071                13.296163                10.944308
# 530530714072                11.536480                 8.195827
# 530530714073                13.269904                 8.468519
# 530530714112                12.285190                 9.615196
#
#               destination_id_03  proximity_traveltime_03  \
# origin_id
# 530530701003          427271369                52.472263
# 530530714071          421027779                16.006815
# 530530714072          421027779                18.268181
# 530530714073          421027779                20.223521
# 530530714112          721714069                16.478653
#
#               proximity_kilometers_03  destination_id_04  ...  \
# origin_id                                                 ...
# 530530701003                44.462895          421027779  ...
# 530530714071                12.366455          721714069  ...
# 530530714072                13.177555          721714069  ...
# 530530714073                13.544703          721714069  ...
# 530530714112                11.395147          421027779  ...
#
#               proximity_kilometers_05  destination_id_06  \
# origin_id
# 530530701003                50.456415          216082099
# 530530714071                18.116390          460556608
# 530530714072                20.609116          460556608
# 530530714073                20.976263          460556608
# 530530714112                20.647334          677129595
#
#               proximity_traveltime_06  proximity_kilometers_06  trip_count_01  \
# origin_id
# 530530701003                58.905164                54.642485            0.0
# 530530714071                35.087418                25.237232            2.0
# 530530714072                34.472733                25.286682            3.0
# 530530714073                35.244881                24.631002            1.0
# 530530714112                30.820496                23.049155            7.0
#
#               trip_count_02  trip_count_03  trip_count_04  trip_count_05  \
# origin_id
# 530530701003            2.0            0.0            0.0            0.0
# 530530714071            2.0            0.0            0.0            0.0
# 530530714072            0.0            0.0            0.0            1.0
# 530530714073            0.0            0.0            0.0            0.0
# 530530714112            0.0            1.0            0.0            0.0
#
#               trip_count_06
# origin_id
# 530530701003            0.0
# 530530714071            0.0
# 530530714072            0.0
# 530530714073            0.0
# 530530714112            0.0
#
# [5 rows x 24 columns]

# %%
demog_df = pd.read_csv(origin_demographics, index_col=0)
demog_df.head()
# Out:
#               F1yearincrements_AGE0_CY  F1yearincrements_AGE1_CY  \
# ID
# 530530701003                      31.0                      25.0
# 530530714071                      27.0                      27.0
# 530530714072                      22.0                      23.0
# 530530714073                      22.0                      21.0
# 530530714112                      23.0                      22.0
#
#               F1yearincrements_AGE2_CY  F1yearincrements_AGE3_CY  \
# ID
# 530530701003                      30.0                      28.0
# 530530714071                      27.0                      25.0
# 530530714072                      15.0                      18.0
# 530530714073                      21.0                      21.0
# 530530714112                      22.0                      23.0
#
#               F1yearincrements_AGE4_CY  F1yearincrements_AGE5_CY  \
# ID
# 530530701003                      35.0                      35.0
# 530530714071                      25.0                      25.0
# 530530714072                      22.0                      11.0
# 530530714073                      21.0                      21.0
# 530530714112                      22.0                      22.0
#
#               F1yearincrements_AGE6_CY  F1yearincrements_AGE7_CY  \
# ID
# 530530701003                      32.0                      24.0
# 530530714071                      25.0                      25.0
# 530530714072                      17.0                      29.0
# 530530714073                      21.0                      21.0
# 530530714112                      22.0                      22.0
#
#               F1yearincrements_AGE8_CY  F1yearincrements_AGE9_CY  ...  \
# ID                                                                ...
# 530530701003                      37.0                      28.0  ...
# 530530714071                      25.0                      25.0  ...
# 530530714072                      24.0                      24.0  ...
# 530530714073                      22.0                      23.0  ...
# 530530714112                      21.0                      21.0  ...
#
#               yearmovedin_ACSOMV2000  yearmovedin_ACSOMV2010  \
# ID
# 530530701003                   287.0                   101.0
# 530530714071                   216.0                    10.0
# 530530714072                   227.0                    75.0
# 530530714073                   100.0                   187.0
# 530530714112                   121.0                    83.0
#
#               yearmovedin_ACSOMV2015  yearmovedin_ACSOWNER  \
# ID
# 530530701003                    46.0                 473.0
# 530530714071                     0.0                 226.0
# 530530714072                     0.0                 536.0
# 530530714073                    13.0                 528.0
# 530530714112                     0.0                 273.0
#
#               yearmovedin_ACSRMV1979  yearmovedin_ACSRMV1980  \
# ID
# 530530701003                     0.0                     0.0
# 530530714071                     0.0                     0.0
# 530530714072                     0.0                     0.0
# 530530714073                     0.0                     0.0
# 530530714112                     0.0                     0.0
#
#               yearmovedin_ACSRMV1990  yearmovedin_ACSRMV2000  \
# ID
# 530530701003                     7.0                    49.0
# 530530714071                    10.0                    13.0
# 530530714072                     0.0                    12.0
# 530530714073                     0.0                    21.0
# 530530714112                    31.0                    13.0
#
#               yearmovedin_ACSRMV2010  yearmovedin_ACSRMV2015
# ID
# 530530701003                    37.0                    23.0
# 530530714071                   110.0                     0.0
# 530530714072                    14.0                    44.0
# 530530714073                    38.0                    21.0
# 530530714112                   103.0                     0.0
#
# [5 rows x 7281 columns]

# %%
final_df = demog_df.join(comp_final_df).join(brand_fnl_df)
final_df.head()
# Out:
#               F1yearincrements_AGE0_CY  F1yearincrements_AGE1_CY  \
# ID
# 530530701003                      31.0                      25.0
# 530530714071                      27.0                      27.0
# 530530714072                      22.0                      23.0
# 530530714073                      22.0                      21.0
# 530530714112                      23.0                      22.0
#
#               F1yearincrements_AGE2_CY  F1yearincrements_AGE3_CY  \
# ID
# 530530701003                      30.0                      28.0
# 530530714071                      27.0                      25.0
# 530530714072                      15.0                      18.0
# 530530714073                      21.0                      21.0
# 530530714112                      22.0                      23.0
#
#               F1yearincrements_AGE4_CY  F1yearincrements_AGE5_CY  \
# ID
# 530530701003                      35.0                      35.0
# 530530714071                      25.0                      25.0
# 530530714072                      22.0                      11.0
# 530530714073                      21.0                      21.0
# 530530714112                      22.0                      22.0
#
#               F1yearincrements_AGE6_CY  F1yearincrements_AGE7_CY  \
# ID
# 530530701003                      32.0                      24.0
# 530530714071                      25.0                      25.0
# 530530714072                      17.0                      29.0
# 530530714073                      21.0                      21.0
# 530530714112                      22.0                      22.0
#
#               F1yearincrements_AGE8_CY  F1yearincrements_AGE9_CY  ...  \
# ID                                                                ...
# 530530701003                      37.0                      28.0  ...
# 530530714071                      25.0                      25.0  ...
# 530530714072                      24.0                      24.0  ...
# 530530714073                      22.0                      23.0  ...
# 530530714112                      21.0                      21.0  ...
#
#               proximity_kilometers_05  destination_id_06  \
# ID
# 530530701003                50.456415        216082099.0
# 530530714071                18.116390        460556608.0
# 530530714072                20.609116        460556608.0
# 530530714073                20.976263        460556608.0
# 530530714112                20.647334        677129595.0
#
#               proximity_traveltime_06  proximity_kilometers_06  trip_count_01  \
# ID
# 530530701003                58.905164                54.642485            0.0
# 530530714071                35.087418                25.237232            2.0
# 530530714072                34.472733                25.286682            3.0
# 530530714073                35.244881                24.631002            1.0
# 530530714112                30.820496                23.049155            7.0
#
#               trip_count_02  trip_count_03  trip_count_04  trip_count_05  \
# ID
# 530530701003            2.0            0.0            0.0            0.0
# 530530714071            2.0            0.0            0.0            0.0
# 530530714072            0.0            0.0            0.0            1.0
# 530530714073            0.0            0.0            0.0            0.0
# 530530714112            0.0            1.0            0.0            0.0
#
#               trip_count_06
# ID
# 530530701003            0.0
# 530530714071            0.0
# 530530714072            0.0
# 530530714073            0.0
# 530530714112            0.0
#
# [5 rows x 7472 columns]

# %%
final_df.to_csv(interim_dir/'training_data.csv')
