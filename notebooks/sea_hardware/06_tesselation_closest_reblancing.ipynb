# %%
import itertools
import os
from pathlib import Path
import pickle
import sys

from arcgis.gis import GIS
from arcgis.features import GeoAccessor
from arcgis.geometry import Geometry
import dask.dataframe
import pandas as pd

sys.path.append('../../src')
from geoai_retail.analysis import get_add_new_closest_dataframe

sys.path.append('../')
import config

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = Path(os.path.abspath('../../data'))
interim_dir = data/'interim'
interim_gdb = interim_dir/'interim.gdb'
raw_dir = data/'raw'
raw_gdb = raw_dir/'raw.gdb'

origin_fc = str(raw_gdb/'sea_block_group')
origin_id_fld = 'ID'

dest_fc = str(raw_gdb/'sea_ace')
dest_id_fld = 'LOCNUM'

comp_fc = raw_gdb/'sea_ace_comp'
comp_id_fld = 'LOCNUM'

real_estate_fc = raw_gdb/'real_estate_hex'
real_estate_id_fld = 'GRID_ID'

closest_brand = interim_dir/'closest_store.csv'
closest_comp = interim_dir/'closest_competition.csv'
origin_demographics = interim_dir/'origin_enrich_all.csv'
inrix_trips = interim_dir/'cust_count_inrix.csv'
training_data = interim_dir/'training_data.csv'

# %%
origin_df = GeoAccessor.from_featureclass(str(origin_fc))
origin_df.head()
# Out:
#    OBJECTID            ID           NAME  \
# 0         1  530530701003  530530701.003
# 1         2  530530714071  530530714.071
# 2         3  530530714072  530530714.072
# 3         4  530530714073  530530714.073
# 4         5  530530714112  530530714.112
#
#                                                SHAPE
# 0  {"rings": [[[-122.06627999999995, 47.076520000...
# 1  {"rings": [[[-122.34031999999996, 47.071510000...
# 2  {"rings": [[[-122.35767999999996, 47.067370000...
# 3  {"rings": [[[-122.36847999999998, 47.067630000...
# 4  {"rings": [[[-122.41108999999994, 47.071690000...

# %%
dest_df = GeoAccessor.from_featureclass(str(dest_fc)).set_index('OBJECTID', drop=True)
dest_df.head()
# Out:
#              LOCNUM                   CONAME               STREET        CITY  \
# OBJECTID
# 1         371889957      GRAHAM ACE HARDWARE           224TH ST E      GRAHAM
# 2         460556608    OAKBROOK ACE HARDWARE   STEILACOOM BLVD SW      TACOMA
# 3         405129289  GIG HARBOR ACE HARDWARE  POINT FOSDICK DR NW  GIG HARBOR
# 4         216082099   SOUTH END ACE HARDWARE        PACIFIC AVE S    SPANAWAY
# 5         721714069             ACE HARDWARE           112TH ST S    PARKLAND
#
#          STATE  STATE_NAME    ZIP  ZIP4     NAICS     SIC  ...  ISCODE  \
# OBJECTID                                                   ...
# 1           WA  Washington  98338  5704  44413005  525104  ...
# 2           WA  Washington  98498  6154  44413005  525104  ...
# 3           WA  Washington  98335  1711  44413005  525104  ...
# 4           WA  Washington  98387  8395  44413005  525104  ...
# 5           WA  Washington  98444  5711  44413005  525104  ...
#
#          SQFTCODE       LOC_NAME  STATUS     SCORE     SOURCE REMOVE NEAR_FID  \
# OBJECTID
# 1               6   PointAddress       M  100.0000  INFOGROUP      0        3
# 2               3  StreetAddress       M   96.3594  INFOGROUP      0       35
# 3               7  StreetAddress       M  100.0000  INFOGROUP      0       41
# 4               5   PointAddress       M  100.0000  INFOGROUP      0       96
# 5               3   PointAddress       M   95.4063  INFOGROUP      0       98
#
#           NEAR_DIST                                              SHAPE
# OBJECTID
# 1          0.000021  {"x": -122.29909999999995, "y": 47.05410000000...
# 2          0.000010  {"x": -122.54489999999998, "y": 47.18000000000...
# 3          0.000019  {"x": -122.57929999999999, "y": 47.30130000000...
# 4         55.586255  {"x": -122.43459999999999, "y": 47.08740000000...
# 5          0.000010  {"x": -122.43199999999996, "y": 47.15610000000...
#
# [5 rows x 25 columns]

# %%
real_estate_df = GeoAccessor.from_featureclass(str(real_estate_fc), where_clause="road_reachable = 1")
real_estate_df = real_estate_df[[real_estate_id_fld, 'SHAPE']].copy()
print(real_estate_df.GRID_ID.dtype)
print(len(real_estate_df.index))
real_estate_df.head()
# Out:
# object
# 1906
#   GRID_ID                                              SHAPE
# 0      28  {"rings": [[[-121.98783159799996, 46.740620218...
# 1      30  {"rings": [[[-121.92611773799996, 46.740620218...
# 2      31  {"rings": [[[-121.89526080699994, 46.728410000...
# 3      32  {"rings": [[[-121.86440387799996, 46.740620218...
# 4      33  {"rings": [[[-121.83354694699995, 46.728410000...

# %%
row = real_estate_df.iloc[0]
row
# Out:
# GRID_ID                                                   28
# SHAPE      {'rings': [[[-121.98783159799996, 46.740620218...
# Name: 0, dtype: object

# %%
def _get_rebalanced_closest_df(x_coord, y_coord, new_location_id):
    
    cnt_geom = Geometry({'x': x_coord, 'y': y_coord, 'spatialReference': real_estate_df.spatial.sr})
    
    # get a dataframe of all potential rebalanced areas
    rebal_df = get_add_new_closest_dataframe(
        origins=origin_df,
        origin_id_field=origin_id_fld,
        destinations=dest_df,
        destination_id_field=dest_id_fld,
        closest_table=closest_brand,
        new_destination=cnt_geom
    )
    
    # while we soved way broader than possilby needed, we check and only keep changed rows
    dest_id_cols = [col for col in rebal_df.columns if col.startswith('destination_id')]
    dest_id_arr = dest_df[dest_id_fld].unique()
    new_rebal_origin_ids = pd.concat([rebal_df[~rebal_df[dest_col].isin(dest_id_arr)]['origin_id'] for dest_col in dest_id_cols]).unique()
    rebal_keep_df = rebal_df[rebal_df['origin_id'].isin(new_rebal_origin_ids)].copy()

    rebal_keep_df['new_destination_id'] = new_location_id
    
    return rebal_keep_df

def get_affected_df(input_df):
    
    df_lst = input_df.apply(lambda row: _get_rebalanced_closest_df(
        row['SHAPE'].centroid[0], row['SHAPE'].centroid[1], row[real_estate_id_fld]), axis=1)
    return pd.concat(test_df.values)

# %%
test_df = get_affected_df(real_estate_df.iloc[500:502], real_estate_id_fld)
test_df
# Out:
# 500            origin_id destination_id_01  proximity...
# 501            origin_id destination_id_01  proximity...
# dtype: object

# %%
pd.concat(test_df.values)
# Out:
#         origin_id destination_id_01  proximity_traveltime_01  \
# 36   530530726011         405129289                21.491815
# 37   530530726012         405129289                22.204510
# 38   530530726013         405129289                23.694928
# 39   530530726022         405129289                25.834003
# 40   530530726023         405129289                28.672600
# 41   530530726031         405129289                34.262404
# 42   530530726032         405129289                36.339953
# 43   530530726034         405129289                36.938191
# 436  530530724051         405129289                21.264023
# 437  530530724052         405129289                12.159949
# 459                22.882152         460556608                36.814868
# 460                25.035145         460556608                40.127845
# 461                23.411419         460556608                36.550806
# 462                19.323115         460556608                30.546076
# 463                17.756254         460556608                26.252104
# 464                37.521193         460556608                42.051817
#
#      proximity_kilometers_03 destination_id_04  proximity_traveltime_04  \
# 36                 38.879325         715571320                55.025679
# 37                 44.155208         715571320                55.248502
# 38                 42.207773         715565781                59.289798
# 39                 46.503610         715565781                59.554341
# 40                 50.200974         715565781                64.267470
# 41                 55.996360         715565781                69.857274
# 42                 58.899579         715565781                71.934823
# 43                 56.277792         715565781                72.533061
# 436                30.155365         721714069                46.676557
# 437                25.590927         721714069                42.262611
# 438                22.544721         721714069                38.961547
# 439                21.344295         721714069                38.057312
# 440                23.460487         721714069                39.990741
# 441                19.174913         721714069                33.729271
# 442                19.074185         721714069                34.524921
# 443                20.704589         721714069                32.298467
# 444                19.997227         721714069                35.755012
# 445                19.205015         721714069                34.861261
# 446                18.766681         721714069                30.898911
# 447                18.979389         721714069                33.911045
# 448                23.855910         721714069                41.261283
# 449                24.392001         721714069                41.490192
# 450                28.274716         721714069                45.509737
# 451                32.322667         721714069                49.761715
# 452                32.061453         715565781                48.652633
# 453                32.183827         715565781                53.331430
# 454                27.237497         721714069                40.070653
# 455                25.376267         721714069                41.070967
# 456                30.421842         715565781                44.038170
# 457                27.722348         715565781                45.604413
# ..                       ...               ...                      ...
# 43                 56.277792         715565781                72.533061
# 436                30.155365         721714069                46.676557
# 437                25.590927         721714069                42.262611
# 438                22.544721         721714069                38.961547
# 439                21.344295         721714069                38.057312
# 440                23.460487         721714069                39.990741
# 441                19.174913         721714069                33.729271
# 442                19.629243         721714069                34.524921
# 443                21.259648         721714069                32.298467
# 444                19.997227         721714069                35.755012
# 445                19.205015         721714069                34.861261
# 446                19.321740         721714069                30.898911
# 447                19.534447         721714069                33.911045
# 448                23.855910         721714069                41.261283
# 449                24.392001         721714069                41.490192
# 450                28.274716         721714069                45.509737
# 451                32.322667         721714069                49.761715
# 452                32.061453         715565781                48.652633
# 453                32.183827         715565781                53.331430
# 454                27.237497         721714069                40.070653
# 455                25.376267         721714069                41.070967
# 456                30.421842         715565781                44.038170
# 457                27.722348         715565781                45.604413
# 458                26.879354         721714069                39.928255
# 459                25.794468         721714069                46.050950
# 460                27.947462         715565781                47.176362
# 461                26.323735         721714069                45.786887
# 462                22.235431         721714069                39.782157
# 463                20.287314         721714069                35.488185
# 464                41.647103         715565781                58.793006
#
#      proximity_kilometers_04 destination_id_05  proximity_traveltime_05  \
# 36                 38.879325         460556608                39.279178
# 37                 44.155208         460556608                39.991873
# 38                 43.924768         715571320                59.289798
# 39                 48.018616         715571320                59.554341
# 40                 51.917969         715571320                64.267470
# 41                 57.713355         715571320                69.857274
# 42                 60.616574         715571320                71.934823
# 43                 57.994787         715571320                72.533061
# 436                36.710388         688834225                41.565639
# 437                32.145950         688834225                37.151692
# 438                29.099744         688834225                33.850629
# 439                27.899318         688834225                32.946393
# 440                30.015511         688834225                34.879822
# 439                32.600060         677129595                35.498154
# 440                34.716252         677129595                37.431583
# 441                30.430679         677129595                31.170114
# 442                29.288341         677129595                31.965763
# 443                27.882200         677129595                29.739309
# 444                31.252992         677129595                33.195854
# 445                30.460780         677129595                32.302103
# 446                27.828033         677129595                28.339753
# 447                29.074453         677129595                31.351887
# 448                35.111675         677129595                38.702126
# 449                35.647767         677129595                38.931034
# 450                39.530482         677129595                42.950579
# 451                43.578433         677129595                47.202557
# 452                35.253242         721714069                43.012540
# 453                38.175475         721714069                43.986518
# 454                38.493262         715565781                55.208966
# 455                36.632032         677129595                38.511809
# 456                30.516230         721714069                51.042949
# 457                31.590462         721714069                48.416437
# 458                35.606127         715571320                50.790064
# 459                34.136795         715571320                47.820812
# 460                32.810838         721714069                49.363926
# 461                35.613274         715571320                49.235627
# 462                33.491196         677129595                37.222999
# 463                31.543079         677129595                32.929027
# 464                43.422392         721714069                47.350176
#
#      proximity_kilometers_06 new_destination_id
# 36                 44.321717               1288
# 37                 49.783201               1288
# 38                 47.631757               1288
# 39                 51.927593               1288
# 40                 55.624958               1288
# 41                 61.420344               1288
# 42                 64.323563               1288
# 43                 61.701776               1288
# 436                41.735620               1288
# 437                37.171182               1288
# 438                34.124976               1288
# 439                32.924550               1288
# 440                35.040742               1288
# 441                30.755168               1288
# 442                29.612830               1288
# 443                28.206690               1288
# 444                31.577482               1288
# 445                30.785270               1288
# 446                28.152522               1288
# 447                29.398943               1288
# 448                35.436165               1288
# 449                35.972257               1288
# 450                39.854971               1288
# 451                43.902923               1288
# 452                38.616476               1288
# 453                38.738851               1288
# 454                38.710607               1288
# 455                36.956522               1288
# 456                36.976865               1288
# 457                34.277372               1288
# ..                       ...                ...
# 43                 61.701776               1289
# 436                41.735620               1289
# 437                37.171182               1289
# 438                34.124976               1289
# 439                32.924550               1289
# 440                35.040742               1289
# 441                30.755168               1289
# 442                29.612830               1289
# 443                28.206690               1289
# 444                31.577482               1289
# 445                30.785270               1289
# 446                28.152522               1289
# 447                29.398943               1289
# 448                35.436165               1289
# 449                35.972257               1289
# 450                39.854971               1289
# 451                43.902923               1289
# 452                38.616476               1289
# 453                38.738851               1289
# 454                38.710607               1289
# 455                36.956522               1289
# 456                36.976865               1289
# 457                34.277372               1289
# 458                35.606127               1289
# 459                34.136795               1289
# 460                34.502485               1289
# 461                35.613274               1289
# 462                33.815686               1289
# 463                31.867569               1289
# 464                47.071086               1289
#
# [74 rows x 20 columns]

# %%
ent_gis = GIS(config.ent_url, username=config.ent_user, password=config.ent_pass)
ent_gis

# %%
import warnings
warnings.filterwarnings('ignore')

real_estate_df.reset_index(inplace=True, drop=True)

for idx, row in real_estate_df.iterrows():
    
    rebal_result = get_affected_df(get_new_tuple(row, real_estate_id_fld))
    
    if idx == 0 and not affected_df:
        affected_df = rebal_result
    else:
        affected_df = affected_df.append(rebal_result)
    print(f'success - {row[0]}')
    
    affected_df.to_csv(affected_csv)

# %%
processing_df = pd.DataFrame(columns=['x_coord', 'y_coord', 'new_location_id'])
processing_df.x_coord = real_estate_df.SHAPE.apply(lambda geom: geom.centroid[0])
processing_df.y_coord = real_estate_df.SHAPE.apply(lambda geom: geom.centroid[1])
processing_df.new_location_id = real_estate_df[real_estate_id_fld]
processing_df.head()
# Out:
#       x_coord    y_coord new_location_id
# 0 -122.008403  46.740619              28
# 1 -121.946689  46.740619              30
# 2 -121.915832  46.728409              31
# 3 -121.884975  46.740619              32
# 4 -121.854118  46.728409              33

# %%
ddf = dask.dataframe.from_pandas(processing_df.iloc[500:502], chunksize=30)

# %%
ddf_lst = ddf.apply(lambda row: _get_rebalanced_closest_df(row[0], row[1], row[2]), axis=1)
ddf_lst
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\dataframe\utils.py in raise_on_meta_error(funcname, udf)
#     169     try:
# --> 170         yield
#     171     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\dataframe\core.py in _emulate(func, *args, **kwargs)
#    4728     with raise_on_meta_error(funcname(func), udf=kwargs.pop("udf", False)):
# -> 4729         return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#    4730
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\utils.py in __call__(self, obj, *args, **kwargs)
#     856     def __call__(self, obj, *args, **kwargs):
# --> 857         return getattr(obj, self.method)(*args, **kwargs)
#     858
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\apply.py in get_result(self)
#     150
# --> 151         return self.apply_standard()
#     152
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#
# <ipython-input-49-4ab73100ef28> in <lambda>(row)
# ----> 1 ddf_lst = ddf.apply(lambda row: _get_rebalanced_closest_df(row[0], row[1], row[2]), axis=1)
#       2 ddf_lst
#
# <ipython-input-35-82b13d97cb0b> in _get_rebalanced_closest_df(x_coord, y_coord, new_location_id)
#      11         closest_table=closest_brand,
# ---> 12         new_destination=cnt_geom
#      13     )
#
# D:\projects\geoai-retail\src\geoai_retail\analysis.py in get_add_new_closest_dataframe(origins, origin_id_field, destinations, destination_id_field, closest_table, new_destination, gis, origin_weighting_points)
#      78                                                          network_dataset=ba_data.usa_network_dataset,
# ---> 79                                                          destination_count=dest_count)
#      80
#
# D:\projects\geoai-retail\src\geoai_retail\proximity_local.py in get_closest_solution(origins, origin_id_fld, destinations, dest_id_fld, gis, network_dataset, destination_count)
#     430         # run the closest analysis locally
# --> 431         closest_df = _get_closest_df_arcpy(origin_df, dest_df, destination_count, network_dataset)
#     432
#
# D:\projects\geoai-retail\src\geoai_retail\proximity_local.py in _get_closest_df_arcpy(origin_df, dest_df, dest_count, network_dataset, max_dist)
#     257     # run the solve, and get comfortable
# --> 258     arcpy.na.Solve(na_lyr)
#     259
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\na.py in Solve(in_network_analysis_layer, ignore_invalids, terminate_on_solve_error, simplification_tolerance, overrides)
#    2707     except Exception as e:
# -> 2708         raise e
#    2709
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\na.py in Solve(in_network_analysis_layer, ignore_invalids, terminate_on_solve_error, simplification_tolerance, overrides)
#    2704     try:
# -> 2705         retval = convertArcObjectToPythonObject(gp.Solve_na(*gp_fixargs((in_network_analysis_layer, ignore_invalids, terminate_on_solve_error, simplification_tolerance, overrides), True)))
#    2706         return retval
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     505         if callable(val):
# --> 506             return lambda *args: val(*gp_fixargs(args, True))
#     507         else:
#
# ExecuteError: ('ERROR 030024: Solve returned a failure.\nInsufficient number of valid locations in "Facilities" or "Incidents".\nFailed to execute (Solve).\n', 'occurred at index 0')
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-4ab73100ef28> in <module>
# ----> 1 ddf_lst = ddf.apply(lambda row: _get_rebalanced_closest_df(row[0], row[1], row[2]), axis=1)
#       2 ddf_lst
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\dataframe\core.py in apply(self, func, axis, broadcast, raw, reduce, args, meta, **kwds)
#    3980         if meta is no_default:
#    3981             meta = _emulate(
# -> 3982                 M.apply, self._meta_nonempty, func, args=args, udf=True, **kwds
#    3983             )
#    3984             warnings.warn(meta_warning(meta))
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\dataframe\core.py in _emulate(func, *args, **kwargs)
#    4727     """
#    4728     with raise_on_meta_error(funcname(func), udf=kwargs.pop("udf", False)):
# -> 4729         return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#    4730
#    4731
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\dataframe\utils.py in raise_on_meta_error(funcname, udf)
#     189         )
#     190         msg = msg.format(" in `{0}`".format(funcname) if funcname else "", repr(e), tb)
# --> 191         raise ValueError(msg)
#     192
#     193
#
# ValueError: Metadata inference failed in `apply`.
#
# You have supplied a custom function and Dask is unable to
# determine the type of output that that function returns.
#
# To resolve this please provide a meta= keyword.
# The docstring of the Dask function you ran should have more information.
#
# Original error is below:
# ------------------------
# ExecuteError('ERROR 030024: Solve returned a failure.\nInsufficient number of valid locations in "Facilities" or "Incidents".\nFailed to execute (Solve).\n', 'occurred at index 0')
#
# Traceback:
# ---------
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\dataframe\utils.py", line 170, in raise_on_meta_error
#     yield
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\dataframe\core.py", line 4729, in _emulate
#     return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\dask\utils.py", line 857, in __call__
#     return getattr(obj, self.method)(*args, **kwargs)
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\frame.py", line 6487, in apply
#     return op.get_result()
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\apply.py", line 151, in get_result
#     return self.apply_standard()
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\apply.py", line 257, in apply_standard
#     self.apply_series_generator()
#   File "C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgis\lib\site-packages\pandas\core\apply.py", line 286, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-49-4ab73100ef28>", line 1, in <lambda>
#     ddf_lst = ddf.apply(lambda row: _get_rebalanced_closest_df(row[0], row[1], row[2]), axis=1)
#   File "<ipython-input-35-82b13d97cb0b>", line 12, in _get_rebalanced_closest_df
#     new_destination=cnt_geom
#   File "../../src\geoai_retail\analysis.py", line 79, in get_add_new_closest_dataframe
#     destination_count=dest_count)
#   File "../../src\geoai_retail\proximity_local.py", line 431, in get_closest_solution
#     closest_df = _get_closest_df_arcpy(origin_df, dest_df, destination_count, network_dataset)
#   File "../../src\geoai_retail\proximity_local.py", line 258, in _get_closest_df_arcpy
#     arcpy.na.Solve(na_lyr)
#   File "C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\na.py", line 2708, in Solve
#     raise e
#   File "C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\na.py", line 2705, in Solve
#     retval = convertArcObjectToPythonObject(gp.Solve_na(*gp_fixargs((in_network_analysis_layer, ignore_invalids, terminate_on_solve_error, simplification_tolerance, overrides), True)))
#   File "C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py", line 506, in <lambda>
#     return lambda *args: val(*gp_fixargs(args, True))
