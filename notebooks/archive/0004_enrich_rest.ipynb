# %%
import os
from arcgis.gis import GIS
from arcgis.features import GeoAccessor
from arcgis.geometry import Geometry
from arcgis.geoenrichment import enrich, Country
import pandas as pd
import numpy as np

import sys
sys.path.append('../src/geoai_retail')
import utils
import config

ent_gis = GIS(config.ent_url, username=config.ent_user, password=config.ent_pass)
ent_gis
# Out:
# GIS @ https://geoai-webgis-ent.bd.esri.com/portal version:7.1

# %%
raw_gdb = r'../data/raw/raw.gdb'
origin_fc = os.path.join(raw_gdb, 'blocks')
origin_id_fld = 'GEOID'

vars_csv = '../data/raw/enrichment_variables.csv'

# %%
geo_fc = origin_fc
geo_id_fld = origin_id_fld

geo_df = utils.get_dataframe(geo_fc)
geo_df = geo_df[[geo_id_fld, 'SHAPE']].copy()
geo_df.head()
# Out:
#              GEOID                                              SHAPE
# 0  410050201001000  {"rings": [[[-122.65566145899999, 45.426378462...
# 1  410050201001001  {"rings": [[[-122.65534145899994, 45.427037462...
# 2  410050201001002  {"rings": [[[-122.65548645999996, 45.429533462...
# 3  410050201001003  {"rings": [[[-122.65696245999999, 45.428736462...
# 4  410050201001004  {"rings": [[[-122.65702845999999, 45.428751462...

# %%
vars_df = pd.read_csv(vars_csv, index_col=0)
vars_df['variable_name'] = vars_df['variable_name'].str.upper()
vars_df.sample(5)
# Out:
#                                    alias       category_id  \
# 998             2018 Asian Pop Age 80-84    agebyracebysex
# 1165   2018 Multiple Races Pop Age 15-19    agebyracebysex
# 107   ACS Pop 18-64 speak Oth/English NW               age
# 1531             2018 Hispanic Asian Pop    hispanicorigin
# 186        2018 Median Disposable Income  disposableincome
#
#               local_enrich_name                       name  \
# 998     agebyracebysex.asn80_cy    agebyracebysex_asn80_cy
# 1165    agebyracebysex.mlt15_cy    agebyracebysex_mlt15_cy
# 107         age.languacsotnwa18        language_acsotnwa18
# 1531  hispanicorigin.hispasn_cy  hispanicorigin_hispasn_cy
# 186   disposableincome.meddi_cy  disposableincome_meddi_cy
#
#                rest_enrich_name    variable_name
# 998     agebyracebysex_asn80_cy         ASN80_CY
# 1165    agebyracebysex_mlt15_cy         MLT15_CY
# 107         age_languacsotnwa18  LANGUACSOTNWA18
# 1531  hispanicorigin_hispasn_cy       HISPASN_CY
# 186   disposableincome_meddi_cy         MEDDI_CY

# %%
vars_df['enrich_name'] = vars_df['category_id'].str.cat(vars_df['variable_name'].str.upper(), sep='.')
vars_df.sample(5)
# Out:
#                                   alias       category_id  \
# 103  ACS Pop 18-64 speak API/English NW               age
# 926  2018 American Indian Pop Age 20-24    agebyracebysex
# 845        2018 White Females Age 25-29    agebyracebysex
# 280    2018 Disposable Inc Base/HHr 75+  disposableincome
# 351       2018 HHr 55-64/Inc $35K-49999               age
#
#                local_enrich_name                         name  \
# 103          age.languacsapnwa18          language_acsapnwa18
# 926       agebyracebysex.ai20_cy       agebyracebysex_ai20_cy
# 845     agebyracebysex.whtf25_cy     agebyracebysex_whtf25_cy
# 280  disposableincome.dia75bascy  disposableincome_dia75bascy
# 351        age.incomebya55i35_cy        incomebyage_a55i35_cy
#
#                 rest_enrich_name      variable_name  \
# 103          age_languacsapnwa18    LANGUACSAPNWA18
# 926       agebyracebysex_ai20_cy            AI20_CY
# 845     agebyracebysex_whtf25_cy          WHTF25_CY
# 280  disposableincome_dia75bascy         DIA75BASCY
# 351        age_incomebya55i35_cy  INCOMEBYA55I35_CY
#
#                      enrich_name
# 103          age.LANGUACSAPNWA18
# 926       agebyracebysex.AI20_CY
# 845     agebyracebysex.WHTF25_CY
# 280  disposableincome.DIA75BASCY
# 351        age.INCOMEBYA55I35_CY

# %%
usa = Country.get('USA')
enrich_df = usa.data_collections
enrich_df['variable_name'] = enrich_df['analysisVariable'].apply(lambda val: val.split('.')[1])
enrich_df.set_index('variable_name', inplace=True)

five_year_out = str(np.max([int(val) for val in enrich_df['vintage'].unique() if pd.notna(val) and not '-' in val]))
enrich_df = enrich_df[enrich_df['vintage'] != five_year_out]

enrich_df.sample(5)
# Out:
#                                     analysisVariable  \
# variable_name
# NHSPAI_CY            raceandhispanicorigin.NHSPAI_CY
# MP05028a_B     LeisureActivitiesLifestyle.MP05028a_B
# MP03001a_I          BabyProductsToysGames.MP03001a_I
# X3009_X                     HousingHousehold.X3009_X
# MP18038a_I             FinancialInsurance.MP18038a_I
#
#                                                            alias  \
# variable_name
# NHSPAI_CY                  2018 Non-Hispanic American Indian Pop
# MP05028a_B                        Bought novel in last 12 months
# MP03001a_I                Index: Used baby food in last 6 months
# X3009_X                             Owned Dwellings: Ground Rent
# MP18038a_I     Index: Have life insurance: separate whole lif...
#
#                                        fieldCategory vintage
# variable_name
# NHSPAI_CY       2018 Race and Hispanic Origin (Esri)    2018
# MP05028a_B     2018 Books & Cards (Market Potential)    2018
# MP03001a_I     2018 Baby Products (Market Potential)    2018
# X3009_X             2018 Housing (Consumer Spending)    2018
# MP18038a_I         2018 Insurance (Market Potential)    2018

# %%
full_enrich_df = vars_df.join(enrich_df, on='variable_name', rsuffix='_online')
full_enrich_df.drop_duplicates('variable_name', inplace=True)
full_enrich_df.dropna(0, subset=['analysisVariable'], inplace=True)
enrich_vars = list(full_enrich_df['analysisVariable'].values)
enrich_vars[:20]
# Out:
# ['AtRisk.GQPOP_CY',
#  'Generations.GENALPHACY',
#  'Generations.GENZ_CY',
#  'Generations.MILLENN_CY',
#  'Generations.GENX_CY',
#  'Generations.BABYBOOMCY',
#  'Generations.OLDRGENSCY',
#  'Generations.GENBASE_CY',
#  '5yearincrements.POP0_CY',
#  '5yearincrements.POP5_CY',
#  '5yearincrements.POP10_CY',
#  '5yearincrements.POP15_CY',
#  '5yearincrements.POP20_CY',
#  '5yearincrements.POP25_CY',
#  '5yearincrements.POP30_CY',
#  '5yearincrements.POP35_CY',
#  '5yearincrements.POP40_CY',
#  '5yearincrements.POP45_CY',
#  '5yearincrements.POP50_CY',
#  '5yearincrements.POP55_CY']

# %%
# %%time
enrich_df = enrich(geo_df, analysis_variables=enrich_vars, return_geometry=False)

# %%
enrich_df.sample(5)

# %%
enriched_result.to_csv('./home/block_enrich_result.csv')
