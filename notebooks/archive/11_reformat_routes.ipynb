# %%
from arcgis.features import GeoAccessor
routes_path = r'D:\projects\geoai-retail\data\interim\interim.gdb\ClosestFacility1\CFRoutes1'

# %%
df = GeoAccessor.from_featureclass(routes_path)
print(len(df.index))
df.head()
# Out:
# 10
#    ObjectID  FacilityID  FacilityRank                      Name  \
# 0         1        1781             1  637497520 - 410510013023
# 1         2        1800             2  666724190 - 410510013023
# 2         3        1802             3  724992959 - 410510013023
# 3         4        1776             4  402794004 - 410510013023
# 4         5        1799             5  439386809 - 410510013023
#
#    IncidentCurbApproach  FacilityCurbApproach  IncidentID StartTime EndTime  \
# 0                     2                     1         649      None    None
# 1                     2                     1         649      None    None
# 2                     1                     1         649      None    None
# 3                     2                     2         649      None    None
# 4                     2                     1         649      None    None
#
#   StartTimeUTC EndTimeUTC Total_Minutes  Total_TravelTime Total_Miles  \
# 0         None       None          None          1.791511        None
# 1         None       None          None          1.797261        None
# 2         None       None          None          2.021772        None
# 3         None       None          None          2.131916        None
# 4         None       None          None          2.159315        None
#
#    Total_Kilometers Total_TimeAt1KPH Total_WalkTime Total_TruckMinutes  \
# 0          0.730751             None           None               None
# 1          0.668861             None           None               None
# 2          0.688978             None           None               None
# 3          0.926105             None           None               None
# 4          0.784228             None           None               None
#
#   Total_TruckTravelTime                                              SHAPE
# 0                  None  {"hasM": true, "paths": [[[-13651821.6007, 570...
# 1                  None  {"hasM": true, "paths": [[[-13651532.17, 57013...
# 2                  None  {"hasM": true, "paths": [[[-13651109.156, 5702...
# 3                  None  {"hasM": true, "paths": [[[-13652099.8994, 570...
# 4                  None  {"hasM": true, "paths": [[[-13651376.0585, 570...

# %%
pair_lst = df.Name.apply(lambda val: val.split(' - '))

# %%
df['destination_id'] = [pair[1] for pair in pair_lst]
df['origin_id'] = [pair[0] for pair in pair_lst]
df['proximity_miles'] = df['Total_Kilometers'] * 0.621371
df.head()
# Out:
#    ObjectID  FacilityID  FacilityRank                      Name  \
# 0         1        1781             1  637497520 - 410510013023
# 1         2        1800             2  666724190 - 410510013023
# 2         3        1802             3  724992959 - 410510013023
# 3         4        1776             4  402794004 - 410510013023
# 4         5        1799             5  439386809 - 410510013023
#
#    IncidentCurbApproach  FacilityCurbApproach  IncidentID StartTime EndTime  \
# 0                     2                     1         649      None    None
# 1                     2                     1         649      None    None
# 2                     1                     1         649      None    None
# 3                     2                     2         649      None    None
# 4                     2                     1         649      None    None
#
#   StartTimeUTC       ...       Total_Miles Total_Kilometers  Total_TimeAt1KPH  \
# 0         None       ...              None         0.730751              None
# 1         None       ...              None         0.668861              None
# 2         None       ...              None         0.688978              None
# 3         None       ...              None         0.926105              None
# 4         None       ...              None         0.784228              None
#
#   Total_WalkTime  Total_TruckMinutes Total_TruckTravelTime  \
# 0           None                None                  None
# 1           None                None                  None
# 2           None                None                  None
# 3           None                None                  None
# 4           None                None                  None
#
#                                                SHAPE destination_id  \
# 0  {"hasM": true, "paths": [[[-13651821.6007, 570...   410510013023
# 1  {"hasM": true, "paths": [[[-13651532.17, 57013...   410510013023
# 2  {"hasM": true, "paths": [[[-13651109.156, 5702...   410510013023
# 3  {"hasM": true, "paths": [[[-13652099.8994, 570...   410510013023
# 4  {"hasM": true, "paths": [[[-13651376.0585, 570...   410510013023
#
#    origin_id proximity_miles
# 0  637497520        0.454068
# 1  666724190        0.415611
# 2  724992959        0.428111
# 3  402794004        0.575455
# 4  439386809        0.487297
#
# [5 rows x 23 columns]

# %%
df_od = df[['origin_id', 'destination_id', 'proximity_miles', 'Total_TravelTime', 'SHAPE']].copy()
df_od.columns = ['origin_id', 'destination_id', 'proximity_miles', 'proximity_drive_time', 'SHAPE']
df_od
# Out:
#    origin_id destination_id  proximity_miles  proximity_drive_time  \
# 0  637497520   410510013023         0.454068              1.791511
# 1  666724190   410510013023         0.415611              1.797261
# 2  724992959   410510013023         0.428111              2.021772
# 3  402794004   410510013023         0.575455              2.131916
# 4  439386809   410510013023         0.487297              2.159315
# 5  417755879   410510013023         0.468911              2.211764
# 6  724497190   410510013023         0.483467              2.259268
# 7  415522508   410510013023         0.575721              2.659192
# 8  404971434   410510013023         0.603943              2.806587
# 9  421989050   410510013023         0.716267              2.920494
#
#                                                SHAPE
# 0  {"hasM": true, "paths": [[[-13651821.6007, 570...
# 1  {"hasM": true, "paths": [[[-13651532.17, 57013...
# 2  {"hasM": true, "paths": [[[-13651109.156, 5702...
# 3  {"hasM": true, "paths": [[[-13652099.8994, 570...
# 4  {"hasM": true, "paths": [[[-13651376.0585, 570...
# 5  {"hasM": true, "paths": [[[-13650808.5934, 570...
# 6  {"hasM": true, "paths": [[[-13650886.5169, 570...
# 7  {"hasM": true, "paths": [[[-13650675.0099, 570...
# 8  {"hasM": true, "paths": [[[-13650649.1326, 570...
# 9  {"hasM": true, "paths": [[[-13652144.4272, 570...

# %%
sdf_od = df_od.set_geometry('SHAPE')
sdf_od.sample(5)
# Out:
#    origin_id destination_id  proximity_miles  proximity_drive_time  \
# 1  666724190   410510013023         0.415611              1.797261
# 3  402794004   410510013023         0.575455              2.131916
# 0  637497520   410510013023         0.454068              1.791511
# 7  415522508   410510013023         0.575721              2.659192
# 8  404971434   410510013023         0.603943              2.806587
#
#                                                SHAPE
# 1  {"hasM": true, "paths": [[[-13651532.17, 57013...
# 3  {"hasM": true, "paths": [[[-13652099.8994, 570...
# 0  {"hasM": true, "paths": [[[-13651821.6007, 570...
# 7  {"hasM": true, "paths": [[[-13650675.0099, 570...
# 8  {"hasM": true, "paths": [[[-13650649.1326, 570...

# %%
df_coffee = GeoAccessor.from_featureclass('D:\\projects\\geoai-retail\\data\\raw\\raw.gdb\\coffee')
df_coffee.sample(5)
# Out:
#      OBJECTID     LOCNUM                 CONAME          STREET       CITY  \
# 512       513  479827917              STARBUCKS   NE WEIDLER ST   PORTLAND
# 548       549  415522509  PORTLAND COFFEE BREAK     SE STARK ST   PORTLAND
# 259       260  721916382              STARBUCKS      SW 6TH AVE   PORTLAND
# 160       161  637497850              STARBUCKS  SW PACIFIC HWY     TIGARD
# 579       580  243189032              STARBUCKS    NE 112TH AVE  VANCOUVER
#
#     STATE  STATE_NAME    ZIP  ZIP4     NAICS  \
# 512    OR      Oregon  97232  1851  72251505
# 548    OR      Oregon  97233  2153  72251505
# 259    OR      Oregon  97204  1102  72251505
# 160    OR      Oregon  97223  8845  72251505
# 579    WA  Washington  98684  4283  72251505
#
#                            ...                         FRNCOD  ISCODE  \
# 512                        ...                              4
# 548                        ...
# 259                        ...                              4
# 160                        ...                              4
# 579                        ...                              4
#
#     SQFTCODE      LOC_NAME  STATUS  SCORE     SOURCE REMOVE open_status  \
# 512        3  PointAddress       M  100.0  INFOGROUP      0        None
# 548        2  PointAddress       M  100.0  INFOGROUP      0        None
# 259        2  PointAddress       M  100.0  INFOGROUP      0        None
# 160        2  PointAddress       M  100.0  INFOGROUP      0        None
# 579        2  PointAddress       M  100.0  INFOGROUP      0        None
#
#                                                  SHAPE
# 512  {"x": -122.63499999995327, "y": 45.53319999958...
# 548  {"x": -122.51430000015557, "y": 45.51960000014...
# 259  {"x": -122.68020000027519, "y": 45.51679999996...
# 160  {"x": -122.75209999966336, "y": 45.44109999976...
# 579  {"x": -122.55670000029824, "y": 45.64129999957...
#
# [5 rows x 25 columns]

# %%
df_coffee = df_coffee[['LOCNUM', 'CONAME']].copy()
df_coffee.set_index('LOCNUM', inplace=True)
df_coffee.sample(5)
# Out:
#                           CONAME
# LOCNUM
# 637352923              STARBUCKS
# 706070672  DUTCH BROTHERS COFFEE
# 388731242    FLOYD'S COFFEE SHOP
# 709126719  DUTCH BROTHERS COFFEE
# 372249466            COFFEE RUSH

# %%
sdf_od = sdf_od.join(df_coffee, on='origin_id')
sdf_od
# Out:
#    origin_id destination_id  proximity_miles  proximity_drive_time  \
# 0  637497520   410510013023         0.454068              1.791511
# 1  666724190   410510013023         0.415611              1.797261
# 2  724992959   410510013023         0.428111              2.021772
# 3  402794004   410510013023         0.575455              2.131916
# 4  439386809   410510013023         0.487297              2.159315
# 5  417755879   410510013023         0.468911              2.211764
# 6  724497190   410510013023         0.483467              2.259268
# 7  415522508   410510013023         0.575721              2.659192
# 8  404971434   410510013023         0.603943              2.806587
# 9  421989050   410510013023         0.716267              2.920494
#
#                                                SHAPE  \
# 0  {"hasM": true, "paths": [[[-13651821.6007, 570...
# 1  {"hasM": true, "paths": [[[-13651532.17, 57013...
# 2  {"hasM": true, "paths": [[[-13651109.156, 5702...
# 3  {"hasM": true, "paths": [[[-13652099.8994, 570...
# 4  {"hasM": true, "paths": [[[-13651376.0585, 570...
# 5  {"hasM": true, "paths": [[[-13650808.5934, 570...
# 6  {"hasM": true, "paths": [[[-13650886.5169, 570...
# 7  {"hasM": true, "paths": [[[-13650675.0099, 570...
# 8  {"hasM": true, "paths": [[[-13650649.1326, 570...
# 9  {"hasM": true, "paths": [[[-13652144.4272, 570...
#
#                           CONAME
# 0                      STARBUCKS
# 1           FLYING CAT COFFEE CO
# 2               PEAKS COFFEE PDX
# 3          COAVA COFFEE ROASTERS
# 4                            TOV
# 5                COFFEE DIVISION
# 6  SEVEN VIRTUES COFFEE ROASTERS
# 7   UNCLE GARY'S COFFEE EMPORIUM
# 8                      STARBUCKS
# 9      K & F SELECT FINE COFFEES

# %%
sdf_od.spatial.to_featureclass('D:\\projects\\geoai-retail\\data\\interim\\interim.gdb\\example_trips')
# Out:
# 'D:\\projects\\geoai-retail\\data\\interim\\interim.gdb\\example_trips'

# %%
from arcgis.gis import GIS
webmap = GIS().map('Portland, OR')
sdf_od.spatial.plot(webmap)
# Out:
# True

# %%
webmap
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-97cd5fb8-b3c5-4267-a8da-c7923e67458c"><img src=""></img></div>
