# %%
import pandas as pd

enrich_csv = r'C:\Users\joel5174\AppData\Local\Temp\2\origin_enrich_all.csv'
nearest_brand_csv = r'C:\Users\joel5174\AppData\Local\Temp\2\nearest_brand.csv'

# %%
enrich_df = pd.read_csv(enrich_csv, index_col=0)
nearest_brand_df = pd.read_csv(nearest_brand_csv, index_col=0)
nearest_brand_df.set_index('origin_id', drop=True, inplace=True)

# %%
enrich_df.set_index('origin_id').join(nearest_brand_df)
# Out:
#               F1yearincrements_AGE0_CY  F1yearincrements_AGE1_CY  \
# origin_id
# 410050203021                      10.0                      10.0
# 410050203022                      27.0                      28.0
# 410050203041                      21.0                      19.0
# 410050203042                       6.0                       8.0
# 410050203043                      24.0                      23.0
# 410050204012                      13.0                       3.0
# 410050204013                      10.0                      10.0
# 410050204014                      11.0                      13.0
# 410050227021                      33.0                      34.0
# 410510064042                      19.0                      18.0
# 410510065012                      28.0                      24.0
# 410510065013                      17.0                      17.0
# 410510066011                      15.0                      17.0
# ...
